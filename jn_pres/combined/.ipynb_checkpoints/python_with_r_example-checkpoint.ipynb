# %% [markdown]
# # Jupyter Notebook demo using Python with R magic
#
# In this notebook we demonstrate the use of Python and R together in a single Jupyter Notebook running Python kernel.
#
# The example is based on data and code in <a href="https://github.com/NoobQuant/ChartLibrary/blob/master/presentations/jupyter_notebooks/code_examples/r/r_example.ipynb">this</a> notebook.

# %% [markdown]
# ## Python part

# %%
# Load dependencies
import pandas as pd # for data wrangling
# %matplotlib notebook
import matplotlib.pyplot as plt # for plots
import seaborn as sns # for improved plot look
import rpy2 # for using R inside Python kernel
import numpy as np # for converting rpy2 objects

# R magic using rpy2!
# %load_ext rpy2.ipython

# %% [markdown]
# ### Load data

# %%
# Read student admission data
df = pd.read_csv('../r/data.csv')

# %%
# Display first observations
df.head()
# Out:
#    admit  gre   gpa  rank
# 0      0  380  3.61     3
# 1      1  660  3.67     3
# 2      1  800  4.00     1
# 3      1  640  3.19     4
# 4      0  520  2.93     4

# %% [markdown]
# ### Explore data by visualizing

# %%
sns.jointplot(df['gpa'],df['gre'],alpha = 0.8, kind = 'hex', size = 6)
# Out:
# C:\Users\ville_000\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# <img src="data:image/png;base64,..." width="600">
# C:\Users\ville_000\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## R part
# We train Self-Organizing Map similarly to the original R example.

# %%
# %%R
# require(kohonen)

# %% [markdown]
# Following runs in R!

# %%
# %%R -i df -o X
#
# # Rename data frame
# data = df
#
# # Get all exogenous variables, dropping endogenous ("admit")
# # z-score normalization for exogenous variables
# X = scale(data[,-1])
#
# # Set seed for reproducibility
# set.seed(222)
#
# # Define SOM grid
# g = somgrid(xdim = 4, ydim = 4, topo = "rectangular")
#
# # Train SOM
# map = som(X,grid=g,alpha=c(0.05,0.01), radius=1)
#
# # Visualize what kind of observations each node contains on average
# plot(map, type="codes")

# %%
# We can inspect from R exported array in Python
X = pd.DataFrame(np.array(X))
display(X.head())
# Out:
#           0         1         2
# 0 -1.798011  0.578348  0.545285
# 1  0.625884  0.736008  0.545285
# 2  1.837832  1.603135 -1.572327
# 3  0.452749 -0.525269  1.604091
# 4 -0.586063 -1.208461  1.604091
